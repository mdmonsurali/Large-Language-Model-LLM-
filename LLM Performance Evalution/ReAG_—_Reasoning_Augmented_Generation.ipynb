# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [66.7 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,315 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,657 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,911 kB]
# Get:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,230 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,526 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,677 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,748 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [34.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:21 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [57.8 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,612 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,609 kB]
# Get:24 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# Fetched 29.0 MB in 3s (8,670 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 121 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 121 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pci.ids all 0.0~2022.01.22-1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 1s (589 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package pci.ids.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Setting up pci.ids (0.0~2022.01.22-1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import threading
import subprocess
import time

def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !ollama pull deepseek-r1:8b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 6340dc3229b0...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   0% ▕▏  58 KB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   0% ▕▏ 5.6 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   1% ▕▏  41 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   2% ▕▏  75 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   2% ▕▏  87 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   2% ▕▏ 117 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   3% ▕▏ 126 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   3% ▕▏ 148 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   4% ▕▏ 178 MB/4.9 GB                  pulling manifest
# pulling 6340dc3229b0...   4% ▕▏ 187 MB/4.9 GB  187 MB/s     25spulling manifest
# pulling 6340dc3229b0...   4% ▕▏ 213 MB/4.9 GB  187 MB/s     25spulling manifest
# pulling 6340dc3229b0...   5% ▕▏ 244 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   5% ▕▏ 265 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   6% ▕▏ 291 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   6% ▕▏ 308 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   7% ▕▏ 347 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   8% ▕▏ 374 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   8% ▕▏ 399 MB/4.9 GB  187 MB/s     24spulling manifest
# pulling 6340dc3229b0...   9% ▕▏ 423 MB/4.9 GB  187 MB/s     23spulling manifest
# pulling 6340dc3229b0...   9% ▕▏ 437 MB/4.9 GB  218 MB/s     20spulling manifest
# pulling 6340dc3229b0...  10% ▕▏ 472 MB/4.9 GB  218 MB/s     20spulling manifest
# pulling 6340dc3229b0...  11% ▕▏ 524 MB/4.9 GB  218 MB/s     20spulling manifest
# pulling 6340dc3229b0...  11% ▕▏ 542 MB/4.9 GB  218 MB/s     20spulling manifest
# pulling 6340dc3229b0...  11% ▕▏ 565 MB/4.9 GB  218 MB/s     19spulling manifest
# pulling 6340dc3229b0...  12% ▕▏ 602 MB/4.9 GB  218 MB/s     19spulling manifest
# pulling 6340dc3229b0...  13% ▕▏ 623 MB/4.9 GB  218 MB/s     19spulling manifest
# pulling 6340dc3229b0...  13% ▕▏ 654 MB/4.9 GB  218 MB/s     19spulling manifest
# pulling 6340dc3229b0...  14% ▕▏ 675 MB/4.9 GB  218 MB/s     19spulling manifest
# pulling 6340dc3229b0...  14% ▕▏ 711 MB/4.9 GB  218 MB/s     19spulling manifest
# pulling 6340dc3229b0...  16% ▕▏ 769 MB/4.9 GB  256 MB/s     16spulling manifest
# pulling 6340dc3229b0...  16% ▕▏ 788 MB/4.9 GB  256 MB/s     16spulling manifest
# pulling 6340dc3229b0...  17% ▕▏ 845 MB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  18% ▕▏ 891 MB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  19% ▕▏ 921 MB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  19% ▕▏ 923 MB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  20% ▕▏ 962 MB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  20% ▕▏ 992 MB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  21% ▕▏ 1.0 GB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  21% ▕▏ 1.0 GB/4.9 GB  256 MB/s     15spulling manifest
# pulling 6340dc3229b0...  22% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  22% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  22% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  22% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  22% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  22% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  23% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  23% ▕▏ 1.1 GB/4.9 GB  270 MB/s     14spulling manifest
# pulling 6340dc3229b0...  24% ▕▏ 1.2 GB/4.9 GB  270 MB/s     13spulling manifest
# pulling 6340dc3229b0...  24% ▕▏ 1.2 GB/4.9 GB  270 MB/s     13spulling manifest
# pulling 6340dc3229b0...  25% ▕▏ 1.2 GB/4.9 GB  270 MB/s     13spulling manifest
# pulling 6340dc3229b0...  25% ▕▏ 1.2 GB/4.9 GB  244 MB/s     15spulling manifest
# pulling 6340dc3229b0...  26% ▕▏ 1.3 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  26% ▕▏ 1.3 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  27% ▕▏ 1.3 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  28% ▕▏ 1.4 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  29% ▕▏ 1.4 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  29% ▕▏ 1.4 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  30% ▕▏ 1.5 GB/4.9 GB  244 MB/s     14spulling manifest
# pulling 6340dc3229b0...  31% ▕▏ 1.5 GB/4.9 GB  244 MB/s     13spulling manifest
# pulling 6340dc3229b0...  31% ▕▏ 1.5 GB/4.9 GB  244 MB/s     13spulling manifest
# pulling 6340dc3229b0...  32% ▕▏ 1.6 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  32% ▕▏ 1.6 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  33% ▕▏ 1.6 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  34% ▕▏ 1.7 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  34% ▕▏ 1.7 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  35% ▕▏ 1.7 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  35% ▕▏ 1.7 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  36% ▕▏ 1.7 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  36% ▕▏ 1.8 GB/4.9 GB  260 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  260 MB/s     11spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  260 MB/s     11spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  257 MB/s     12spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  37% ▕▏ 1.8 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  38% ▕▏ 1.9 GB/4.9 GB  225 MB/s     13spulling manifest
# pulling 6340dc3229b0...  39% ▕▏ 1.9 GB/4.9 GB  211 MB/s     14spulling manifest
# pulling 6340dc3229b0...  40% ▕▏ 2.0 GB/4.9 GB  211 MB/s     14spulling manifest
# pulling 6340dc3229b0...  40% ▕▏ 2.0 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  40% ▕▏ 2.0 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  41% ▕▏ 2.0 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  42% ▕▏ 2.1 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  42% ▕▏ 2.1 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  43% ▕▏ 2.1 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  44% ▕▏ 2.1 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  44% ▕▏ 2.2 GB/4.9 GB  211 MB/s     13spulling manifest
# pulling 6340dc3229b0...  45% ▕▏ 2.2 GB/4.9 GB  223 MB/s     12spulling manifest
# pulling 6340dc3229b0...  46% ▕▏ 2.3 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  46% ▕▏ 2.3 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  47% ▕▏ 2.3 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  48% ▕▏ 2.4 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  48% ▕▏ 2.4 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  49% ▕▏ 2.4 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  50% ▕▏ 2.4 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  50% ▕▏ 2.4 GB/4.9 GB  223 MB/s     11spulling manifest
# pulling 6340dc3229b0...  51% ▕▏ 2.5 GB/4.9 GB  223 MB/s     10spulling manifest
# pulling 6340dc3229b0...  51% ▕▏ 2.5 GB/4.9 GB  231 MB/s     10spulling manifest
# pulling 6340dc3229b0...  52% ▕▏ 2.5 GB/4.9 GB  231 MB/s     10spulling manifest
# pulling 6340dc3229b0...  52% ▕▏ 2.6 GB/4.9 GB  231 MB/s     10spulling manifest
# pulling 6340dc3229b0...  52% ▕▏ 2.6 GB/4.9 GB  231 MB/s     10spulling manifest
# pulling 6340dc3229b0...  53% ▕▏ 2.6 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  54% ▕▏ 2.6 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  54% ▕▏ 2.7 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  55% ▕▏ 2.7 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  55% ▕▏ 2.7 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  55% ▕▏ 2.7 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  56% ▕▏ 2.8 GB/4.9 GB  231 MB/s      9spulling manifest
# pulling 6340dc3229b0...  56% ▕▏ 2.8 GB/4.9 GB  221 MB/s      9spulling manifest
# pulling 6340dc3229b0...  57% ▕▏ 2.8 GB/4.9 GB  221 MB/s      9spulling manifest
# pulling 6340dc3229b0...  57% ▕▏ 2.8 GB/4.9 GB  221 MB/s      9spulling manifest
# pulling 6340dc3229b0...  58% ▕▏ 2.9 GB/4.9 GB  221 MB/s      9spulling manifest
# pulling 6340dc3229b0...  58% ▕▏ 2.9 GB/4.9 GB  221 MB/s      9spulling manifest
# pulling 6340dc3229b0...  59% ▕▏ 2.9 GB/4.9 GB  221 MB/s      9spulling manifest
# pulling 6340dc3229b0...  60% ▕▏ 2.9 GB/4.9 GB  221 MB/s      8spulling manifest
# pulling 6340dc3229b0...  60% ▕▏ 3.0 GB/4.9 GB  221 MB/s      8spulling manifest
# pulling 6340dc3229b0...  60% ▕▏ 3.0 GB/4.9 GB  221 MB/s      8spulling manifest
# pulling 6340dc3229b0...  61% ▕▏ 3.0 GB/4.9 GB  221 MB/s      8spulling manifest
# pulling 6340dc3229b0...  62% ▕▏ 3.0 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  62% ▕▏ 3.0 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  63% ▕▏ 3.1 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  63% ▕▏ 3.1 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  63% ▕▏ 3.1 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  64% ▕▏ 3.1 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  64% ▕▏ 3.2 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  65% ▕▏ 3.2 GB/4.9 GB  214 MB/s      8spulling manifest
# pulling 6340dc3229b0...  65% ▕▏ 3.2 GB/4.9 GB  214 MB/s      7spulling manifest
# pulling 6340dc3229b0...  66% ▕▏ 3.2 GB/4.9 GB  214 MB/s      7spulling manifest
# pulling 6340dc3229b0...  66% ▕▏ 3.3 GB/4.9 GB  226 MB/s      7spulling manifest
# pulling 6340dc3229b0...  67% ▕▏ 3.3 GB/4.9 GB  226 MB/s      7spulling manifest
# pulling 6340dc3229b0...  67% ▕▏ 3.3 GB/4.9 GB  226 MB/s      7spulling manifest
# pulling 6340dc3229b0...  68% ▕▏ 3.3 GB/4.9 GB  226 MB/s      7spulling manifest
# pulling 6340dc3229b0...  68% ▕▏ 3.4 GB/4.9 GB  226 MB/s      6spulling manifest
# pulling 6340dc3229b0...  69% ▕▏ 3.4 GB/4.9 GB  226 MB/s      6spulling manifest
# pulling 6340dc3229b0...  69% ▕▏ 3.4 GB/4.9 GB  226 MB/s      6spulling manifest
# pulling 6340dc3229b0...  69% ▕▏ 3.4 GB/4.9 GB  226 MB/s      6spulling manifest
# pulling 6340dc3229b0...  70% ▕▏ 3.4 GB/4.9 GB  226 MB/s      6spulling manifest
# pulling 6340dc3229b0...  70% ▕▏ 3.4 GB/4.9 GB  226 MB/s      6spulling manifest
# pulling 6340dc3229b0...  70% ▕▏ 3.5 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  71% ▕▏ 3.5 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  71% ▕▏ 3.5 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  72% ▕▏ 3.5 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  72% ▕▏ 3.6 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  73% ▕▏ 3.6 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  74% ▕▏ 3.6 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  74% ▕▏ 3.6 GB/4.9 GB  211 MB/s      6spulling manifest
# pulling 6340dc3229b0...  75% ▕▏ 3.7 GB/4.9 GB  211 MB/s      5spulling manifest
# pulling 6340dc3229b0...  75% ▕▏ 3.7 GB/4.9 GB  211 MB/s      5spulling manifest
# pulling 6340dc3229b0...  76% ▕▏ 3.7 GB/4.9 GB  213 MB/s      5spulling manifest
# pulling 6340dc3229b0...  76% ▕▏ 3.7 GB/4.9 GB  213 MB/s      5spulling manifest
# pulling 6340dc3229b0...  77% ▕▏ 3.8 GB/4.9 GB  213 MB/s      5spulling manifest
# pulling 6340dc3229b0...  77% ▕▏ 3.8 GB/4.9 GB  213 MB/s      5spulling manifest
# pulling 6340dc3229b0...  77% ▕▏ 3.8 GB/4.9 GB  213 MB/s      5spulling manifest
# pulling 6340dc3229b0...  78% ▕▏ 3.8 GB/4.9 GB  213 MB/s      5spulling manifest
# pulling 6340dc3229b0...  78% ▕▏ 3.9 GB/4.9 GB  213 MB/s      4spulling manifest
# pulling 6340dc3229b0...  79% ▕▏ 3.9 GB/4.9 GB  213 MB/s      4spulling manifest
# pulling 6340dc3229b0...  79% ▕▏ 3.9 GB/4.9 GB  213 MB/s      4spulling manifest
# pulling 6340dc3229b0...  80% ▕▏ 3.9 GB/4.9 GB  213 MB/s      4spulling manifest
# pulling 6340dc3229b0...  80% ▕▏ 3.9 GB/4.9 GB  213 MB/s      4spulling manifest
# pulling 6340dc3229b0...  81% ▕▏ 4.0 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  82% ▕▏ 4.0 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  82% ▕▏ 4.0 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  83% ▕▏ 4.1 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  83% ▕▏ 4.1 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  84% ▕▏ 4.1 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  85% ▕▏ 4.2 GB/4.9 GB  239 MB/s      3spulling manifest
# pulling 6340dc3229b0...  86% ▕▏ 4.2 GB/4.9 GB  239 MB/s      2spulling manifest
# pulling 6340dc3229b0...  86% ▕▏ 4.2 GB/4.9 GB  239 MB/s      2spulling manifest
# pulling 6340dc3229b0...  87% ▕▏ 4.3 GB/4.9 GB  239 MB/s      2spulling manifest
# pulling 6340dc3229b0...  88% ▕▏ 4.3 GB/4.9 GB  267 MB/s      2spulling manifest
# pulling 6340dc3229b0...  88% ▕▏ 4.3 GB/4.9 GB  267 MB/s      2spulling manifest
# pulling 6340dc3229b0...  89% ▕▏ 4.4 GB/4.9 GB  267 MB/s      2spulling manifest
# pulling 6340dc3229b0...  89% ▕▏ 4.4 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  90% ▕▏ 4.4 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  90% ▕▏ 4.4 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  91% ▕▏ 4.5 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  91% ▕▏ 4.5 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  92% ▕▏ 4.5 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  92% ▕▏ 4.5 GB/4.9 GB  267 MB/s      1spulling manifest
# pulling 6340dc3229b0...  92% ▕▏ 4.5 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  92% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  261 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  93% ▕▏ 4.6 GB/4.9 GB  225 MB/s      1spulling manifest
# pulling 6340dc3229b0...  95% ▕▏ 4.7 GB/4.9 GB  206 MB/s      1spulling manifest
# pulling 6340dc3229b0...  95% ▕▏ 4.7 GB/4.9 GB  206 MB/s      1spulling manifest
# pulling 6340dc3229b0...  96% ▕▏ 4.7 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  96% ▕▏ 4.7 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  97% ▕▏ 4.8 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  97% ▕▏ 4.8 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  97% ▕▏ 4.8 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  98% ▕▏ 4.8 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  98% ▕▏ 4.8 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  98% ▕▏ 4.8 GB/4.9 GB  206 MB/s      0spulling manifest
# pulling 6340dc3229b0...  99% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0...  99% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0...  99% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0...  99% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  204 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  183 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  183 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB/4.9 GB  183 MB/s      0spulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347...   0% ▕▏    0 B/ 387 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347...   0% ▕▏    0 B/ 387 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347...   0% ▕▏    0 B/ 387 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f...   0% ▕▏    0 B/1.1 KB                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f...   0% ▕▏    0 B/1.1 KB                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd...   0% ▕▏    0 B/ 148 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd...   0% ▕▏    0 B/ 148 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02...   0% ▕▏    0 B/ 487 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02...   0% ▕▏    0 B/ 487 B                  pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B                         pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# ...
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 6340dc3229b0... 100% ▕▏ 4.9 GB
# pulling 369ca498f347... 100% ▕▏  387 B
# pulling 6e4c38e1172f... 100% ▕▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕▏  148 B
# pulling 0cb05c6e4e02... 100% ▕▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !pip install reag   # Install the ReAG library
# Out:
# Collecting reag
#   Downloading reag-0.0.6-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx<0.26.0,>=0.25.0 (from reag)
#   Downloading httpx-0.25.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting litellm<2.0.0,>=1.60.0 (from reag)
#   Downloading litellm-1.61.6-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from reag) (2.10.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->reag) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->reag) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->reag) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->reag) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.26.0,>=0.25.0->reag) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.26.0,>=0.25.0->reag) (0.14.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.60.0->reag) (3.11.10)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.60.0->reag) (8.1.7)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.60.0->reag) (8.5.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.60.0->reag) (3.1.4)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.60.0->reag) (4.23.0)
# Collecting openai>=1.61.0 (from litellm<2.0.0,>=1.60.0->reag)
#   Downloading openai-1.63.2-py3-none-any.whl.metadata (27 kB)
# Collecting python-dotenv>=0.2.0 (from litellm<2.0.0,>=1.60.0->reag)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting tiktoken>=0.7.0 (from litellm<2.0.0,>=1.60.0->reag)
#   Downloading tiktoken-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.60.0->reag) (0.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->reag) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->reag) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->reag) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.60.0->reag) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.60.0->reag) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->reag) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->reag) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->reag) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->reag) (0.22.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.61.0->litellm<2.0.0,>=1.60.0->reag) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.61.0->litellm<2.0.0,>=1.60.0->reag) (0.8.2)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.61.0->litellm<2.0.0,>=1.60.0->reag) (4.67.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.26.0,>=0.25.0->reag) (1.2.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.7.0->litellm<2.0.0,>=1.60.0->reag) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.7.0->litellm<2.0.0,>=1.60.0->reag) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->reag) (1.18.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers->litellm<2.0.0,>=1.60.0->reag) (0.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->reag) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->reag) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->reag) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->reag) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm<2.0.0,>=1.60.0->reag) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm<2.0.0,>=1.60.0->reag) (2.2.3)
# Downloading reag-0.0.6-py3-none-any.whl (5.7 kB)
# Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 4.9 MB/s eta 0:00:00
# Downloading litellm-1.61.6-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 76.1 MB/s eta 0:00:00
# Downloading openai-1.63.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 37.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading tiktoken-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.2 MB/s eta 0:00:00
# Installing collected packages: python-dotenv, tiktoken, httpx, openai, litellm, reag
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.57.4
#     Uninstalling openai-1.57.4:
#       Successfully uninstalled openai-1.57.4
# Successfully installed httpx-0.25.2 litellm-1.61.6 openai-1.63.2 python-dotenv-1.0.1 reag-0.0.6 tiktoken-0.9.0

# %%
# !curl http://localhost:11434
# Should return "Ollama is running"
# Out:
# Ollama is running

# %%
import asyncio
import nest_asyncio
from reag.client import ReagClient, Document

# Needed for async in Colab
nest_asyncio.apply()

async def main():
    async with ReagClient(
        model="ollama/deepseek-r1:8b",
        model_kwargs={"api_base": "http://localhost:11434"}
    ) as client:
        docs = [
            Document(
                name="Superagent",
                content="Superagent is a workspace for AI-agents that learn, perform work, and collaborate.",
                metadata={
                    "url": "https://superagent.sh",
                    "source": "web"
                }
            )
        ]
        response = await client.query("What is Superagent?", documents=docs)
        print("Response:", response)

# Run the async function
await main()
# Out:
# Response: [QueryResult(content='Superagent is a platform that facilitates the collaboration of AI-agents to achieve complex tasks through shared learning and coordination. It enables collective problem-solving by integrating various AI entities.', reasoning="Okay, so I'm trying to figure out what Superagent is based on the information provided. Let me read through the content again. It says that Superagent is a workspace for AI-agents that learn, perform work, and collaborate. Hmm, that's a bit abstract. I'm not entirely sure what exactly it entails.\n\nI know that AI-agents can be programs or systems designed to automate tasks, but combining them into a workspace where they can learn and collaborate sounds like it's meant to manage multiple agents together. Maybe it's some kind of platform that allows different AI entities to work together, share information, and improve over time through collaboration.\n\nThe source is from the Superagent website, which I could check if I had access, but based on the content given, it seems like it's focused on agent coordination and teamwork. It might be used in various industries where automation and distributed tasks are necessary, like healthcare or finance.\n\nI'm not sure about specific use cases or whether it's open-source or proprietary, but from what's provided, Superagent is a tool that brings AI-agents together to achieve complex tasks through their combined abilities and learning processes.", is_irrelevant=True, document=Document(name='Superagent', content='Superagent is a workspace for AI-agents that learn, perform work, and collaborate.', metadata={'url': 'https://superagent.sh', 'source': 'web'}))]

# %%
import asyncio
import nest_asyncio
from reag.client import ReagClient, Document

# Enable async in Colab
nest_asyncio.apply()

async def main():
    async with ReagClient(
        model="ollama/deepseek-r1:8b",
        model_kwargs={
            "api_base": "http://localhost:11434",
            "temperature": 0.3  # Control randomness
        }
    ) as client:
        # Prepare documents
        docs = [
            Document(
                name="Superagent",
                content="Superagent is a workspace for AI-agents that learn, perform work, and collaborate.",
                metadata={
                    "url": "https://superagent.sh",
                    "source": "web",
                    "relevance_score": 0.95  # Custom confidence metric
                }
            )
        ]

        # Execute query
        response = await client.query(
            "What is Superagent?",
            documents=docs,
            options={"filter": [{"key": "source", "value": "web", "operator": "equals"}]}
        )

        print("Answer:", response.content)
        print("Confidence:", response.document.metadata.get("relevance_score"))

await main()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-8-d767f386931f> in <cell line: 39>()
#      37         print("Confidence:", response.document.metadata.get("relevance_score"))
#      38
# ---> 39 await main()
#
# <ipython-input-8-d767f386931f> in main()
#      16         # Prepare documents
#      17         docs = [
# ---> 18             Document(
#      19                 name="Superagent",
#      20                 content="Superagent is a workspace for AI-agents that learn, perform work, and collaborate.",
#
# /usr/local/lib/python3.10/dist-packages/pydantic/main.py in __init__(self, **data)
#     212         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213         __tracebackhide__ = True
# --> 214         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215         if self is not validated_self:
#     216             warnings.warn(
#
# ValidationError: 2 validation errors for Document
# metadata.relevance_score.str
#   Input should be a valid string [type=string_type, input_value=0.95, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# metadata.relevance_score.int
#   Input should be a valid integer, got a number with a fractional part [type=int_from_float, input_value=0.95, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.10/v/int_from_float
